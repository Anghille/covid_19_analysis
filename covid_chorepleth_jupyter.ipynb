# %% [markdown]
# # Coronavirus choropleth maps
#
# A choropleth map is a type of thematic map where areas or regions are shaded in proportion to a given data variable. The data that I used to create the following visualizations is the Novel Corona Virus 2019 dataset from Kaggle. <br><br><br>
#
# *Static choropleth maps* are most useful when you want to compare a desired variable by region. For example, if you wanted to compare the crime rate of each state in the US at a given moment, you could visualize it with a static choropleth.<br><br>
# *An animated or dynamic choropleth map* is similar to a static choropleth map, except that you can compare a variable by region,over time. This adds a third dimension of information and is what makes these visualizations so interesting and powerful.

# %% [markdown]
# #### Importing libraries

# %%
import numpy as np
import pandas as pd
import plotly as py
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### Reading Data

# %%
covid_data = pd.read_csv("../Coronavirus chorepleth map/Data/covid_19_data.csv")
covid_data.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %% [markdown]
# #### Renaming columns

# %%
covid_data.rename(columns={"Country/Region":"Country", "ObservationDate":"Date"}, inplace=True)

# %% [markdown]
# #### Manipulation dataframe

# %%
covid_data_countries = covid_data.groupby(['Country','Date']).sum().reset_index().sort_values('Date', ascending=False)

# %% [markdown]
# #### Creating the Choropleth

# %%
figure = go.Figure(data=go.Choropleth(
    locations=covid_data_countries['Country'],
    locationmode='country names',
    z=covid_data_countries['Confirmed'],
    colorscale='Reds',
    marker_line_color='black',
    marker_line_width=0.5
))

figure.update_layout(
    title_text='Confirmed Cases of March 28, 2020',
    title_x=0.5,
    geo=dict(
        showframe=False,
        showcoastlines=False,
        projection_type="equirectangular"
    )
)
# Out:
# <div>
#
#
#             <div id="01e426c7-e084-4a04-87bb-d6af736f2f9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("01e426c7-e084-4a04-87bb-d6af736f2f9b")) {
#                     Plotly.newPlot(
#                         '01e426c7-e084-4a04-87bb-d6af736f2f9b',
#                         [{"colorscale": [[0.0, "rgb(255,245,240)"], [0.125, "rgb(254,224,210)"], [0.25, "rgb(252,187,161)"], [0.375, "rgb(252,146,114)"], [0.5, "rgb(251,106,74)"], [0.625, "rgb(239,59,44)"], [0.75, "rgb(203,24,29)"], [0.875, "rgb(165,15,21)"], [1.0, "rgb(103,0,13)"]], "locationmode": "country names", "locations": ["Bahamas", "Djibouti", "Guyana", "Bhutan", "Hungary", "New Zealand", "Malawi", "El Salvador", "Burkina Faso", "Chile", "Antigua and Barbuda", "Sudan", "Madagascar", "France", "Vietnam", "Switzerland", "Kosovo", "Grenada", "Libya", "Saint Vincent and the Grenadines", "Colombia", "Poland", "Estonia", "Israel", "Kuwait", "Russia", "Malta", "Finland", "Tunisia", "Slovenia", "Papua New Guinea", "Sweden", "Bulgaria", "Seychelles", "Iran", "Honduras", "Paraguay", "South Africa", "Mozambique", "Togo", "Jamaica", "Lebanon", "Macau", "Romania", "Cyprus", "Senegal", "Ecuador", "Gambia", "Central African Republic", "US", "Burundi", "Nicaragua", "Azerbaijan", "Diamond Princess", "Burma", "Argentina", "Belgium", "Portugal", "Chad", "Western Sahara", "Afghanistan", "Japan", "Gabon", "Greece", "Laos", "Luxembourg", "Mali", "Norway", "Iraq", "Uzbekistan", "North Macedonia", "South Sudan", "Bosnia and Herzegovina", "Barbados", "Ethiopia", "Kenya", "Ireland", "Saint Kitts and Nevis", "Guinea", "Mauritius", "Botswana", "Thailand", "Montenegro", "Jordan", "Nepal", "Pakistan", "Saudi Arabia", "Croatia", "Algeria", "Egypt", "United Arab Emirates", "Sao Tome and Principe", "UK", "MS Zaandam", "Guinea-Bissau", "Philippines", "Costa Rica", "Morocco", "Turkey", "Spain", "Syria", "Eswatini", "Panama", "South Korea", "Bolivia", "Venezuela", "Brunei", "Fiji", "Mauritania", "Guatemala", "Cuba", "Suriname", "Latvia", "Oman", "Lesotho", "Monaco", "Namibia", "Netherlands", "Comoros", "Bahrain", "Angola", "Equatorial Guinea", "Yemen", "Brazil", "Rwanda", "Congo (Brazzaville)", "Tajikistan", "Albania", "Mainland China", "Belarus", "Andorra", "Denmark", "Bangladesh", "Timor-Leste", "Mexico", "San Marino", "Hong Kong", "Congo (Kinshasa)", "Uganda", "Liberia", "Cabo Verde", "Malaysia", "Armenia", "Moldova", "Ukraine", "Sierra Leone", "Trinidad and Tobago", "Italy", "Taiwan", "Iceland", "Nigeria", "Czech Republic", "Haiti", "Qatar", "Dominica", "Maldives", "Mongolia", "Germany", "Niger", "Serbia", "Slovakia", "Eritrea", "Austria", "Holy See", "Sri Lanka", "Georgia", "Dominican Republic", "Lithuania", "Kyrgyzstan", "Ivory Coast", "Kazakhstan", "Uruguay", "Cameroon", "Saint Lucia", "Canada", "West Bank and Gaza", "Somalia", "Ghana", "Zambia", "Australia", "Singapore", "Indonesia", "Cambodia", "Peru", "Liechtenstein", "Tanzania", "Zimbabwe", "Belize", "Benin", "India", "Netherlands", "Namibia", "Brunei", "Morocco", "Monaco", "Uruguay", "Turkey", "Oman", "Bosnia and Herzegovina", "Cameroon", "Latvia", "Comoros", "Mauritania", "Guatemala", "Cuba", "Slovakia", "Saint Lucia", "Costa Rica", "Fiji", "Philippines", "Equatorial Guinea", "Suriname", "Kazakhstan", "Venezuela", "Bahrain", "Papua New Guinea", "Israel", "Ghana", "Kuwait", "Russia", "Malta", "Eswatini", "Austria", "Finland", "Slovenia", "Zimbabwe", "Sri Lanka", "Cabo Verde", "Australia", "Bulgaria", "Sweden", "Iraq", "Liechtenstein", "Honduras", "Panama", "Spain", "Uzbekistan", "Lithuania", "Yemen", "Angola", "India", "Rwanda", "Malaysia", "Italy", "South Korea", "Pakistan", "United Arab Emirates", "Cambodia", "Haiti", "Egypt", "Nepal", "Jordan", "Algeria", "Qatar", "Thailand", "Montenegro", "Croatia", "Botswana", "Guinea", "Dominica", "South Sudan", "Saint Kitts and Nevis", "Ireland", "Mongolia", "Kenya", "Belize", "Saudi Arabia", "Ethiopia", "Barbados", "Sao Tome and Principe", "Mauritius", "Syria", "Nigeria", "Brazil", "Somalia", "Guinea-Bissau", "Congo (Brazzaville)", "Kyrgyzstan", "Tajikistan", "Albania", "MS Zaandam", "Germany", "UK", "Mainland China", "Belarus", "Andorra", "Denmark", "Moldova", "Bangladesh", "Trinidad and Tobago", "Tanzania", "Kosovo", "Timor-Leste", "San Marino", "U ...
